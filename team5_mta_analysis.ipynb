# %%
# Out:
# Package                   Version
# ------------------------- ------------
# anyio                     4.2.0
# argon2-cffi               21.3.0
# argon2-cffi-bindings      21.2.0
# asttokens                 2.0.5
# async-lru                 2.0.4
# attrs                     23.1.0
# Babel                     2.11.0
# beautifulsoup4            4.12.2
# bleach                    4.1.0
# bokeh                     3.3.4
# Bottleneck                1.3.7
# Brotli                    1.0.9
# Cartopy                   0.22.0
# census                    0.8.21
# certifi                   2024.2.2
# cffi                      1.16.0
# cftime                    1.6.2
# charset-normalizer        2.0.4
# citipy                    0.0.6
# click                     8.1.7
# click-plugins             1.1.1
# cligj                     0.7.2
# cloudpickle               2.2.1
# colorama                  0.4.6
# colorcet                  3.1.0
# comm                      0.2.1
# ...
